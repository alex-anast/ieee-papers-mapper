# %%
# Import CNN Zero-Shot & other necessary stuff
from transformers import pipeline

# For Scheduler, data mining
from apscheduler.schedulers.background import BackgroundScheduler as Scheduler
import requests, datetime, time, json, re

import pandas as pd

# For data input and data cleaning
from nltk.tokenize import regexp_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from numpy import NaN
from numpy.random import randint
from stop_words import get_stop_words

# Custom libraries
import Universal_DataEdit_GeoLoc as u_geoloc
import Universal_Scheduler as u_sch
import Universal_DataEdit_Affiliations as u_aff
import Training_OBC as obc
import Training_SiC as sic
import Training_GaN as gan
import Training_Inverter as inv
import Training_DCDC as dcdc

# ----- ----- ----- ----- -----  ----- ----- ----- ----- ----- -----
# GLOBALS
cep_api_dir = "/home/aan0709@tmme/pcu-research-mapping/data/IEEE_test/"
# ----- ----- ----- ----- -----  ----- ----- ----- ----- ----- -----


def openExcel(excel_name, sheet_name, current_dir):
    df = pd.read_excel(current_dir + excel_name + ".xlsx", sheet_name=sheet_name)
    return df


file_name = "Inverter_finished"
file_name_sheet = "Sheet1"

df = openExcel(file_name, file_name_sheet, cep_api_dir)

# %%
for i in range(len(df)):
    temp = df.loc[i, "Country"].split(";")
    temp2 = df.loc[i, "Continent"].split(";")
    len_t = len(temp)
    len_t2 = len(temp2)
    if len_t != len_t2:
        print("Here")
        print(i)
print(df.loc[848, "Country"])
print(df.loc[848, "Continent"])
print(df.loc[848, "Affiliation"])
# Out:
# Here
# 848
# Azerbaijan; Azerbaijan
# Europe; Asia; Europe; Asia
# Uncategorized;Uncategorized

# %%
# ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# DATA EDIT AFFILIATIONS TIME KEYWORDS

# Check for trash columns:
del_id = []
for i in range(len(df.columns)):
    if "Unnamed" in df.columns[i]:
        del_id.append(i)
for i in range(len(del_id) - 1, -1, -1):
    df = df.drop(df.columns[del_id[i]], axis=1)

# Now there is a DataFrame filled with the Data's category. Time to edit:
df.reset_index(inplace=True, drop=True)

ieee_keywords_col = "index_terms.ieee_terms.terms"
author_keywords_col = "index_terms.author_terms.terms"

# Making data readable:
df = u_aff.editAffiliations(df)  # Affiliations (Location)
df = u_aff.editCalendar(df)  # Calendar (exact Date)
df = u_aff.editTerms(df, ieee_keywords_col)  # IEEE Keywords
df = u_aff.editTerms(df, author_keywords_col)  # Authors' Keywords
# ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----


# ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# DATA EDIT EXTRACT GEOLOCATION

# loc init
batch_size = 32
df["Country"] = NaN
df["Continent"] = NaN

# Call def locZS
countries, continents = u_geoloc.loadGeoLocData()
df = u_geoloc.cleanIndexes(df)
candidate_labels, hypothesis_template, classifierGPU = u_geoloc.loadZeroShot(
    0, countries
)
df = u_geoloc.locZS(
    df,
    batch_size,
    candidate_labels,
    hypothesis_template,
    countries,
    continents,
    classifierGPU,
)
# ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# Out:
# Affiliations Edit:
# Processed 101/101 papers.
#
# Calendar Edit:
# Processed 101/101 papers.
#
# Terms Edit (authors first, ieee second):
# Processed 101/101 papers.
#
# Terms Edit (authors first, ieee second):
# Processed 101/101 papers.
# Pipeline loaded in 11.135 seconds.
#
# Geolocation:
# # Countries to find : 96
# //----- ----- -----
# UNCATEGORIZED :  Clarkson University 24
# UNCATEGORIZED :  Cree Lighting Company 69
# //----- ----- -----
# Singapore---Asia
# Taiwan---Asia
# USA---North America
# Spain---Europe
# Taiwan---Asia
# USA---North America
# Taiwan---Asia
# Slovakia---Europe
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# France---Europe
# USA---North America
# USA---North America
# USA---North America
# Japan---Asia
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# Uncategorized---Uncategorized
# USA---North America
# Singapore---Asia
# South Korea---Asia
# Taiwan---Asia
# USA---North America
# Taiwan---Asia
# Finland---Europe
# Taiwan---Asia
# Japan---Asia
# China---Asia
# Taiwan---Asia
# USA---North America
# USA---North America
# USA---North America
# Uncategorized---Uncategorized
# Uncategorized---Uncategorized
# Taiwan---Asia
# Taiwan---Asia
# Ireland---Europe
# China---Asia
# USA---North America
# USA---North America
# USA---North America
# Brazil---South America
# USA---North America
# USA---North America
# Canada---North America
# USA---North America
# Uncategorized---Uncategorized
# Uncategorized---Uncategorized
# Uncategorized---Uncategorized
# USA---North America
# Canada---North America
# Canada---North America
# USA---North America
# USA---North America
# Taiwan---Asia
# USA---North America
# Canada---North America
# Singapore---Asia
# Singapore---Asia
# Singapore---Asia
# USA---North America
# China---Asia
# Uncategorized---Uncategorized
# India---Asia
# USA---North America
# Germany---Europe
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# Singapore---Asia
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# USA---North America
# France---Europe
# UK---Europe
# USA---North America
# USA---North America
# USA---North America
# Taiwan---Asia
# Taiwan---Asia
# USA---North America
# USA---North America
# Taiwan---Asia
# Taiwan---Asia
# Taiwan---Asia
# USA---North America
# Singapore---Asia
# USA---North America
# Taiwan---Asia
# USA---North America
# Taiwan---Asia
# #Papers = 101, Time Total Elapsed: 0 min 31.77 sec
# Time Elapsed : 31.77
# # Uncategorized : 2

# %%
ieee_keywords_col = "index_terms.ieee_terms.terms"
author_keywords_col = "index_terms.author_terms.terms"


def excludeAffiliations(df):
    # Find the University / Institute / Laboratory of the affiliation:
    count = 0
    for i in range(len(df)):
        if i == 39:
            print(df.loc[i, "authors.authors"])
            print(df.loc[i, "Country"])
            print(df.loc[i, "Continent"])
        if isinstance(df.loc[i, "authors.authors"], float):
            df.loc[i, "Affiliation"] = "Uncategorized"
            continue
        temp = df.loc[i, "authors.authors"].split(";")
        for j in range(len(temp)):
            if temp[j] == "https":
                continue
            else:
                temp2 = temp[j].split(",")
                final_data = []
                for k in range(len(temp2)):
                    if (
                        "niversi" in temp2[k]
                        or "niv." in temp2[k]
                        or "nstitut" in temp2[k]
                        or "aborat" in temp2[k]
                        or "nst." in temp2[k]
                        or "Acad." in temp2[k]
                        or "Lab." in temp2[k]
                        or "Labs." in temp2[k]
                    ):
                        data = temp2[k]
                        while data[0] == " ":
                            data = data[1:]
                        final_data.append(data)
                if len(final_data) == 0:
                    count += 1
                    final_data.append("Uncategorized")
                df.loc[i, "Affiliation"] = ";".join(final_data)
    for i in range(len(df)):
        if isinstance(df.loc[i, "Affiliation"], float):
            df.loc[i, "Affiliation"] = "Uncategorized"
    for i in range(len(df)):
        print(
            str(df.loc[i, "Affiliation"])
            + "---"
            + df.loc[i, "Country"]
            + "---"
            + df.loc[i, "Continent"]
            + "---"
            + str(i)
        )
        lc = len(df.loc[i, "Country"].split(";"))
        lC = len(df.loc[i, "Continent"].split(";"))
        la = len(df.loc[i, "Affiliation"].split(";"))
        if lc != lC:
            print("ERROR")
    for i in range(len(df)):
        list_aff = df.loc[i, "Affiliation"].split(";")
        list_cou = df.loc[i, "Country"].split(";")
        la = len(list_aff)
        lc = len(list_cou)
        while (lc - la) != 0:
            list_aff = list_aff[1:]
            la = len(list_aff)
        df.loc[i, "Affiliation"] = ";".join(list_aff)
        print(
            str(df.loc[i, "Affiliation"])
            + "---"
            + df.loc[i, "Country"]
            + "---"
            + df.loc[i, "Continent"]
            + "---"
            + str(i)
        )
    print(
        "%d/%d valid Affiliations, or the %.2f precent."
        % (len(df) - count, len(df), 100 * ((len(df) - count) / len(df)))
    )
    return df


df["Affiliation"] = NaN
df = excludeAffiliations(df)
# Out:
# https;https;https;https;https
# Uncategorized
# Uncategorized
# Nanyang Technol. Univ.---Singapore---Asia---0
# Nat. Cheng Kung Univ.---Taiwan---Asia---1
# Boston Univ.---USA---North America---2
# Univ. Politecnica de Madrid---Spain---Europe---3
# Nat. Cheng Kung Univ.---Taiwan---Asia---4
# Nat. High Magnetic Field Lab.;Florida State Univ.---USA---North America---5
# Nat. Cheng Kung Univ.---Taiwan---Asia---6
# Inst. of Electr. Eng.;Slovak Acad. of Sci.---Slovakia---Europe---7
# North Carolina State Univ.---USA---North America---8
# New Mexico Univ.---USA---North America---9
# South Carolina Univ.---USA---North America---10
# South Carolina Univ.---USA---North America---11
# Illinois Univ.---USA---North America---12
# South Carolina Univ.---USA---North America---13
# TIGER Common Lab.;Inst. dElectronique et de Microelectronique du Nord---France---Europe---14
# Uncategorized---USA---North America---15
# North Carolina State Univ.---USA---North America---16
# Northwestern Univ.---USA---North America---17
# Meijo Univ.---Japan---Asia---18
# California Univ.---USA---North America---19
# Virginia Polytech. Inst. & State Univ.---USA---North America---20
# Naval Res. Lab.---USA---North America---21
# Air Force Res. Lab.---USA---North America---22
# Semicond. Technol. Lab.---USA---North America---23
# Clarkson University---Uncategorized---Uncategorized---24
# California Univ.---USA---North America---25
# Nat. Univ. of Singapore---Singapore---Asia---26
# Chonbuk Nat. Univ.---South Korea---Asia---27
# Inst. of Microelectron.;Nat. Cheng Kung Univ.---Taiwan---Asia---28
# Nanoelectronics Lab.;Cincinnati Univ.---USA---North America---29
# Nat. Central Univ.---Taiwan---Asia---30
# Tampere Univ. of Technol.---Finland---Europe---31
# Nat. Taiwan Univ.---Taiwan---Asia---32
# Uncategorized---Japan---Asia---33
# Hong Kong Univ.---China---Asia---34
# Nat. Cheng Kung Univ.---Taiwan---Asia---35
# Rochester Inst. of Technol.---USA---North America---36
# Illinois Univ.---USA---North America---37
# California Univ.---USA---North America---38
# Uncategorized---Uncategorized---Uncategorized---39
# Uncategorized---Uncategorized---Uncategorized---40
# Nat. Cheng Kung Univ.---Taiwan---Asia---41
# Nat. Cheng Kung Univ.---Taiwan---Asia---42
# University College---Ireland---Europe---43
# Southwest Research Institute of Applied Magnetics---China---Asia---44
# University of Missouri-Rolla---USA---North America---45
# AT&T Bell Laboratories---USA---North America---46
# Uncategorized---USA---North America---47
# Inst. di Fisica;Univ. Federal do Rio Grande do Sul---Brazil---South America---48
# Bell Telephone Labs.---USA---North America---49
# Uncategorized---USA---North America---50
# Uncategorized---Canada---North America---51
# HRL Labs. LLC---USA---North America---52
# Uncategorized---Uncategorized---Uncategorized---53
# Uncategorized---Uncategorized---Uncategorized---54
# Uncategorized---Uncategorized---Uncategorized---55
# Ohio State Univ.---USA---North America---56
# Sherbrooke Univ.---Canada---North America---57
# Sherbrooke Univ.---Canada---North America---58
# Uncategorized---USA---North America---59
# Bell Laboratories---USA---North America---60
# Nat. Central Univ.---Taiwan---Asia---61
# University of Wisconsin---USA---North America---62
# Saskatchewan Univ.---Canada---North America---63
# Nat. Univ. of Singapore---Singapore---Asia---64
# Temasek Labs.;Nat. Univ. of Singapore---Singapore---Asia---65
# Nat. Univ. of Singapore---Singapore---Asia---66
# Lucent Technol. Bell Labs.---USA---North America---67
# Zhejiang Univ.---China---Asia---68
# Uncategorized---Uncategorized---Uncategorized---69
# Univ. of Delhi---India---Asia---70
# Cornell Univ.---USA---North America---71
# Univ. of Ulm---Germany---Europe---72
# Univ. of California---USA---North America---73
# Univ. of California---USA---North America---74
# Uncategorized---USA---North America---75
# Uncategorized---USA---North America---76
# Nanyang Technol. Univ.---Singapore---Asia---77
# Univ. of California---USA---North America---78
# Uncategorized---USA---North America---79
# Duke Univ.---USA---North America---80
# Rutgers Univ.---USA---North America---81
# Micro & Nanotechnology Lab.;Univ. of Illinois---USA---North America---82
# Inst. dElectronique et de Microelectronique du Nord---France---Europe---83
# Inst. of Photonics;Univ. of Strathclyde---UK---Europe---84
# Uncategorized---USA---North America---85
# Georgia Inst. of Technol.---USA---North America---86
# Georgia Inst. of Technol.---USA---North America---87
# Nat. Cheng Kung Univ.---Taiwan---Asia---88
# Inst. of Opt. Sci.;Nat. Central Univ.---Taiwan---Asia---89
# Lucent Technol. Bell Labs.---USA---North America---90
# Georgia Inst. of Technol.---USA---North America---91
# Nat. Cheng Kung Univ.---Taiwan---Asia---92
# Opto-Electron. & Syst. Labs.;Ind. Technol. Res. Inst.---Taiwan---Asia---93
# Opto-Electron. & Syst. Labs.;Ind. Technol. Res. Inst.---Taiwan---Asia---94
# Purdue Univ.---USA---North America---95
# Nat. Technol. Univ.---Singapore---Asia---96
# Univ. of South Carolina---USA---North America---97
# Nat. Cheng Kung Univ.---Taiwan---Asia---98
# Univ. of California---USA---North America---99
# Nat. Central Univ.---Taiwan---Asia---100
# Nanyang Technol. Univ.---Singapore---Asia---0
# Nat. Cheng Kung Univ.---Taiwan---Asia---1
# Boston Univ.---USA---North America---2
# Univ. Politecnica de Madrid---Spain---Europe---3
# Nat. Cheng Kung Univ.---Taiwan---Asia---4
# Florida State Univ.---USA---North America---5
# Nat. Cheng Kung Univ.---Taiwan---Asia---6
# Slovak Acad. of Sci.---Slovakia---Europe---7
# North Carolina State Univ.---USA---North America---8
# New Mexico Univ.---USA---North America---9
# South Carolina Univ.---USA---North America---10
# South Carolina Univ.---USA---North America---11
# Illinois Univ.---USA---North America---12
# South Carolina Univ.---USA---North America---13
# Inst. dElectronique et de Microelectronique du Nord---France---Europe---14
# Uncategorized---USA---North America---15
# North Carolina State Univ.---USA---North America---16
# Northwestern Univ.---USA---North America---17
# Meijo Univ.---Japan---Asia---18
# California Univ.---USA---North America---19
# Virginia Polytech. Inst. & State Univ.---USA---North America---20
# Naval Res. Lab.---USA---North America---21
# Air Force Res. Lab.---USA---North America---22
# Semicond. Technol. Lab.---USA---North America---23
# Clarkson University---Uncategorized---Uncategorized---24
# California Univ.---USA---North America---25
# Nat. Univ. of Singapore---Singapore---Asia---26
# Chonbuk Nat. Univ.---South Korea---Asia---27
# Nat. Cheng Kung Univ.---Taiwan---Asia---28
# Cincinnati Univ.---USA---North America---29
# Nat. Central Univ.---Taiwan---Asia---30
# Tampere Univ. of Technol.---Finland---Europe---31
# Nat. Taiwan Univ.---Taiwan---Asia---32
# Uncategorized---Japan---Asia---33
# Hong Kong Univ.---China---Asia---34
# Nat. Cheng Kung Univ.---Taiwan---Asia---35
# Rochester Inst. of Technol.---USA---North America---36
# Illinois Univ.---USA---North America---37
# California Univ.---USA---North America---38
# Uncategorized---Uncategorized---Uncategorized---39
# Uncategorized---Uncategorized---Uncategorized---40
# Nat. Cheng Kung Univ.---Taiwan---Asia---41
# Nat. Cheng Kung Univ.---Taiwan---Asia---42
# University College---Ireland---Europe---43
# Southwest Research Institute of Applied Magnetics---China---Asia---44
# University of Missouri-Rolla---USA---North America---45
# AT&T Bell Laboratories---USA---North America---46
# Uncategorized---USA---North America---47
# Univ. Federal do Rio Grande do Sul---Brazil---South America---48
# Bell Telephone Labs.---USA---North America---49
# Uncategorized---USA---North America---50
# Uncategorized---Canada---North America---51
# HRL Labs. LLC---USA---North America---52
# Uncategorized---Uncategorized---Uncategorized---53
# Uncategorized---Uncategorized---Uncategorized---54
# Uncategorized---Uncategorized---Uncategorized---55
# Ohio State Univ.---USA---North America---56
# Sherbrooke Univ.---Canada---North America---57
# Sherbrooke Univ.---Canada---North America---58
# Uncategorized---USA---North America---59
# Bell Laboratories---USA---North America---60
# Nat. Central Univ.---Taiwan---Asia---61
# University of Wisconsin---USA---North America---62
# Saskatchewan Univ.---Canada---North America---63
# Nat. Univ. of Singapore---Singapore---Asia---64
# Nat. Univ. of Singapore---Singapore---Asia---65
# Nat. Univ. of Singapore---Singapore---Asia---66
# Lucent Technol. Bell Labs.---USA---North America---67
# Zhejiang Univ.---China---Asia---68
# Uncategorized---Uncategorized---Uncategorized---69
# Univ. of Delhi---India---Asia---70
# Cornell Univ.---USA---North America---71
# Univ. of Ulm---Germany---Europe---72
# Univ. of California---USA---North America---73
# Univ. of California---USA---North America---74
# Uncategorized---USA---North America---75
# Uncategorized---USA---North America---76
# Nanyang Technol. Univ.---Singapore---Asia---77
# Univ. of California---USA---North America---78
# Uncategorized---USA---North America---79
# Duke Univ.---USA---North America---80
# Rutgers Univ.---USA---North America---81
# Univ. of Illinois---USA---North America---82
# Inst. dElectronique et de Microelectronique du Nord---France---Europe---83
# Univ. of Strathclyde---UK---Europe---84
# Uncategorized---USA---North America---85
# Georgia Inst. of Technol.---USA---North America---86
# Georgia Inst. of Technol.---USA---North America---87
# Nat. Cheng Kung Univ.---Taiwan---Asia---88
# Nat. Central Univ.---Taiwan---Asia---89
# Lucent Technol. Bell Labs.---USA---North America---90
# Georgia Inst. of Technol.---USA---North America---91
# Nat. Cheng Kung Univ.---Taiwan---Asia---92
# Ind. Technol. Res. Inst.---Taiwan---Asia---93
# Ind. Technol. Res. Inst.---Taiwan---Asia---94
# Purdue Univ.---USA---North America---95
# Nat. Technol. Univ.---Singapore---Asia---96
# Univ. of South Carolina---USA---North America---97
# Nat. Cheng Kung Univ.---Taiwan---Asia---98
# Univ. of California---USA---North America---99
# Nat. Central Univ.---Taiwan---Asia---100
# 73/101 valid Affiliations, or the 72.28 precent.

# %%
for i in range(len(df)):
    print(
        str(df.loc[i, "Affiliation"])
        + "---"
        + df.loc[i, "Country"]
        + "---"
        + df.loc[i, "Continent"]
        + "---"
        + str(i)
    )
# Out:
# Nat. Univ. of Singapore---Singapore---Asia---0
# Chonbuk Nat. Univ.---South Korea---Asia---1
# Nat. Cheng Kung Univ.---Taiwan---Asia---2
# Cincinnati Univ.---USA---North America---3
# Nat. Central Univ.---Taiwan---Asia---4

# %%
df
# Out:
#                                               abstract  \
# 0    In this letter, we re-examine the completeness...
# 1    A charge asymmetric resonance tunneling (CART)...
# 2    We present the first physics-based nonstationa...
# 3    Successive reactive ion etchings (RIE) were pe...
# 4    An InGaN-GaN blue light-emitting diode (LED) s...
# ..                                                 ...
# 96   Silicon wafer bonding technology is becoming o...
# 97   An advantage for some wide bandgap materials, ...
# 98   GaN Schottky diodes were built internally insi...
# 99   N-p-n Al/sub 0.05/GaN/GaN heterojunction bipol...
# 100  Unlike the conventional layer structure of an ...
#
#                                       abstract_url access_type  \
# 0    https://ieeexplore.ieee.org/document/1001651/      LOCKED
# 1    https://ieeexplore.ieee.org/document/1003762/      LOCKED
# 2    https://ieeexplore.ieee.org/document/1004216/      LOCKED
# 3    https://ieeexplore.ieee.org/document/1004217/      LOCKED
# 4    https://ieeexplore.ieee.org/document/1012381/      LOCKED
# ..                                             ...         ...
# 96   https://ieeexplore.ieee.org/document/1198045/      LOCKED
# 97   https://ieeexplore.ieee.org/document/1198071/      LOCKED
# 98   https://ieeexplore.ieee.org/document/1202503/      LOCKED
# 99   https://ieeexplore.ieee.org/document/1202507/      LOCKED
# 100  https://ieeexplore.ieee.org/document/1202512/      LOCKED
#
#      article_number  citing_paper_count  citing_patent_count content_type  \
# 0           1001651                  13                    0     Journals
# 1           1003762                  49                    2     Journals
# 2           1004216                  10                    5     Journals
# 3           1004217                  20                    0     Journals
# 4           1012381                  70                    2     Journals
# ..              ...                 ...                  ...          ...
# 96          1198045                  10                    5     Journals
# 97          1198071                 331                    1     Journals
# 98          1202503                  59                   26     Journals
# 99          1202507                  38                    0     Journals
# 100         1202512                  21                    0     Journals
#
#                           doi end_page  \
# 0    10.1109/LSP.2002.1001651      136
# 1    10.1109/TED.2002.1003762     1095
# 2    10.1109/LED.2002.1004216      305
# 3    10.1109/LED.2002.1004217      308
# 4    10.1109/LPT.2002.1012381      910
# ..                        ...      ...
# 96    10.1109/TSM.2003.811886      318
# 97   10.1109/TPEL.2003.810840      914
# 98    10.1109/LED.2003.809043      131
# 99    10.1109/LED.2003.811400      143
# 100   10.1109/LED.2003.809533      158
#
#                                           html_url  ...  rank start_page  \
# 0    https://ieeexplore.ieee.org/document/1001651/  ...     1        133
# 1    https://ieeexplore.ieee.org/document/1003762/  ...     2       1093
# 2    https://ieeexplore.ieee.org/document/1004216/  ...     3        303
# 3    https://ieeexplore.ieee.org/document/1004217/  ...     4        306
# 4    https://ieeexplore.ieee.org/document/1012381/  ...     5        908
# ..                                             ...  ...   ...        ...
# 96   https://ieeexplore.ieee.org/document/1198045/  ...    97        314
# 97   https://ieeexplore.ieee.org/document/1198071/  ...    98        907
# 98   https://ieeexplore.ieee.org/document/1202503/  ...    99        129
# 99   https://ieeexplore.ieee.org/document/1202507/  ...   100        141
# 100  https://ieeexplore.ieee.org/document/1202512/  ...   101        156
#
#                                                  title volume  \
# 0    On the completeness of the lattice factorizati...      9
# 1    InGaN/GaN tunnel-injection blue light-emitting...     49
# 2    Physics-based modeling of submicron GaN permea...     23
# 3    Effect of p-doped overlayer thickness on RF-di...     23
# 4    Nitride-based cascade near white light-emittin...     14
# ..                                                 ...    ...
# 96   Temperature and stress distribution in the SOI...     16
# 97   An assessment of wide bandgap semiconductors f...     18
# 98   Improved ESD protection by combining InGaN-GaN...     24
# 99   Very high voltage operation (&gt;330 V) with h...     24
# 100  High-brightness inverted InGaN-GaN multiple-qu...     24
#
#                                        authors.authors  \
# 0    Sch. of Electr. & Electron. Eng., Nanyang Tech...
# 1    Dept. of Electr. Eng., Nat. Cheng Kung Univ., ...
# 2    Dept. of Electr. & Comput. Eng., Boston Univ.,...
# 3    Departamento de Ingenieria Electronica, Univ. ...
# 4    Dept. of Electr. Eng., Nat. Cheng Kung Univ., ...
# ..                                                 ...
# 96   Sch. of Electr. & Electron. Eng., Nat. Technol...
# 97   Dept. of Electr. Eng., Univ. of South Carolina...
# 98   Dept. of Electr. Eng., Nat. Cheng Kung Univ., ...
# 99   Electr. & Comput. Eng. Dept., Univ. of Califor...
# 100  Dept. of Electr. Eng., Nat. Central Univ., Chu...
#
#                           index_terms.ieee_terms.terms  \
# 0    Lattices;Filter bank;Gallium nitride;Matrices;...
# 1    Light-emitting diodes;Resonant tunneling devic...
# 2    Gallium nitride;Monte Carlo methods;Predictive...
# 3    Gallium nitride;JFETs;Molecular beam epitaxial...
# 4    Light emitting diodes;Gallium nitride;Quantum ...
# ..                                                 ...
# 96   Temperature distribution;Fabrication;Thermal s...
# 97   Wide band gap semiconductors;Photonic band gap...
# 98   Electrostatic discharge;Protection;Quantum wel...
# 99   Voltage;Aluminum gallium nitride;Gallium nitri...
# 100  Quantum well devices;Light emitting diodes;Gal...
#
#     index_terms.author_terms.terms    Country      Continent  \
# 0                                   Singapore           Asia
# 1                                      Taiwan           Asia
# 2                                         USA  North America
# 3                                       Spain         Europe
# 4                                      Taiwan           Asia
# ..                             ...        ...            ...
# 96                                  Singapore           Asia
# 97                                        USA  North America
# 98                                     Taiwan           Asia
# 99                                        USA  North America
# 100                                    Taiwan           Asia
#
#                      Affiliation
# 0         Nanyang Technol. Univ.
# 1          Nat. Cheng Kung Univ.
# 2                   Boston Univ.
# 3    Univ. Politecnica de Madrid
# 4          Nat. Cheng Kung Univ.
# ..                           ...
# 96           Nat. Technol. Univ.
# 97       Univ. of South Carolina
# 98         Nat. Cheng Kung Univ.
# 99           Univ. of California
# 100           Nat. Central Univ.
#
# [101 rows x 29 columns]

# %%
for i in range(len(df)):
    lc = len(df.loc[i, "Country"].split(";"))
    lC = len(df.loc[i, "Continent"].split(";"))
    la = len(df.loc[i, "Affiliation"].split(";"))
    if lc != lC:
        print("ERROR")

# %%
for i in range(len(df)):
    list_aff = df.loc[i, "Affiliation"].split(";")
    list_cou = df.loc[i, "Country"].split(";")
    la = len(list_aff)
    lc = len(list_cou)
    while (lc - la) != 0:
        print(
            str(df.loc[i, "Affiliation"])
            + "---"
            + df.loc[i, "Country"]
            + "---"
            + df.loc[i, "Continent"]
            + "---"
            + str(i)
        )
        list_aff = list_aff[1:]
        la = len(list_aff)
    print(list_aff)
    df.loc[i, "Affiliation"] = ";".join(list_aff)
# Out:
# ['Nat. Univ. of Singapore']
# ['Chonbuk Nat. Univ.']
# Inst. of Microelectron.;Nat. Cheng Kung Univ.---Taiwan---Asia---2
# ['Nat. Cheng Kung Univ.']
# Nanoelectronics Lab.;Cincinnati Univ.---USA---North America---3
# ['Cincinnati Univ.']
# ['Nat. Central Univ.']

# %%
def excludeAffiliations(df):
    # Find the University / Institute / Laboratory of the affiliation:
    count = 0
    for i in range(len(df)):
        if isinstance(df.loc[i, "authors.authors"], float):
            df.loc[i, "Affiliation"] = "Uncategorized"
            continue
        temp = df.loc[i, "authors.authors"].split(";")
        for j in range(len(temp)):
            if temp[j] == "https":
                continue
            else:
                temp2 = temp[j].split(",")
                final_data = []
                for k in range(len(temp2)):
                    if "niversi" in temp2[k] or "niv." in temp2[k] or "nstitut" in temp2[k] or "aborat" in temp2[k] or "nst." in temp2[k]
                    or "Acad." in temp2[k] or "Sci." in temp2[k] or "Lab." in temp2[k] or "Labs." in temp2[k]# or "Acad." in temp2[k] or "Acad." in temp2[k] :
                        count += 1
                        data = temp2[k]
                        while data[0] == " ":
                            data = data[1:]
                        final_data.append(data)
                    else:
                        print(temp2[k])
                if len(final_data) == 0:
                    final_data.append("Uncategorized")
                df.loc[i, "Affiliation"] = ";".join(final_data)            
    print("%d/%d valid Affiliations, or the %.2f precent." % (count, len(df), 100*(count/len(df))))
    return df

df["Affiliation"] = NaN
df = excludeAffiliations(df)
# Out:
#  Slovak Acad. of Sci.
#  Bratislava
#  Slovakia
# Dept. of Electr. & Comput. Eng.
#  Urbana
#  IL
#  USA
# Dept. of Electr. & Comput. Eng.
#  Urbana
#  IL
#  USA
# Dept. of Electr. & Comput. Eng.
#  Urbana
#  IL
#  USA
# Dept. of Electr. & Comput. Eng.
#  Urbana
#  IL
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# Dept. of Electr. Eng.
#  Columbia
#  SC
#  USA
# TIGER Common Lab.
#  Villeneuve dAscq
#  France
#  authorUrl
# TIGER Common Lab.
#  Villeneuve dAscq
#  France
#  authorUrl
# TIGER Common Lab.
#  Villeneuve dAscq
#  France
#  authorUrl
# TIGER Common Lab.
#  Villeneuve dAscq
#  France
#  authorUrl
# TIGER Common Lab.
#  Villeneuve dAscq
#  France
#  authorUrl
# Gen. Electr. Corporate Res. & Dev.
#  Niskayuna
#  NY
#  USA
# Dept. of Mater. Sci. & Eng.
#  Raleigh
#  NC
#  USA
# Dept. of Electr. & Comput. Eng.
#  Santa Barbara
#  CA
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Air Force Res. Lab.
#  Wright-Patterson AFB
#  OH
#  USA
# Dept. of Electr. & Comput. Eng.
#  Santa Barbara
#  CA
#  USA
# Dept. of Electr. & Comput. Eng.
#  Santa Barbara
#  CA
#  USA
# Dept. of Electr. & Comput. Eng.
#  Santa Barbara
#  CA
#  USA
# Dept. of Electr. & Comput. Eng.
#  Santa Barbara
#  CA
#  USA
# Dept. of Electr. Eng.
#  NY
#  USA
# Dept. of Electr. & Comput. Eng.
#  Champaign
#  IL
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
# HRL Labs. LLC
#  Malibu
#  CA
#  USA
#  Que.
#  Canada
#  Que.
#  Canada
#  Que.
#  Canada
#  Que.
#  Canada
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Cree Lighting Company
# Dept. of Electron. Sci.
#  New Delhi
#  India
# Dept. of Electron. Sci.
#  New Delhi
#  India
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Sch. of Electr. & Comput. Eng.
#  Ithaca
#  NY
#  USA
# Dept. of Electron Devices & Circuits
#  Germany
# Dept. of Electron Devices & Circuits
#  Germany
# Dept. of Electron Devices & Circuits
#  Germany
# Dept. of Electron Devices & Circuits
#  Germany
# Electr. & Comput. Eng. Dept.
#  Santa Barbara
#  CA
#  USA
# Electr. & Comput. Eng. Dept.
#  Santa Barbara
#  CA
#  USA
# Electr. & Comput. Eng. Dept.
#  Santa Barbara
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Dept. of Electr. Eng.
#  Los Angeles
#  CA
#  USA
# Nitronex Corp.
#  Raleigh
#  NC
#  USA
# Nitronex Corp.
#  Raleigh
#  NC
#  USA
# Nitronex Corp.
#  Raleigh
#  NC
#  USA
# Nitronex Corp.
#  Raleigh
#  NC
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Space & Electron. Group
#  Redondo Beach
#  CA
#  USA
# TRW Electron. & Technol. Div.
#  Redondo Beach
#  CA
#  USA
# TRW Electron. & Technol. Div.
#  Redondo Beach
#  CA
#  USA
# Micro & Nanotechnology Lab.
#  Urbana
#  IL
#  USA
# Micro & Nanotechnology Lab.
#  Urbana
#  IL
#  USA
# Micro & Nanotechnology Lab.
#  Urbana
#  IL
#  USA
# Dept. Hyperfrequences et Semiconducteurs
#  Villeneuve dAscq
#  France
#  authorUrl
# Dept. Hyperfrequences et Semiconducteurs
#  Villeneuve dAscq
#  France
#  authorUrl
# Dept. Hyperfrequences et Semiconducteurs
#  Villeneuve dAscq
#  France
#  authorUrl
# Dept. Hyperfrequences et Semiconducteurs
#  Villeneuve dAscq
#  France
#  authorUrl
# Dept. Hyperfrequences et Semiconducteurs
#  Villeneuve dAscq
#  France
#  authorUrl
# Yamacraw Design Center
#  Atlanta
#  GA
#  USA
# Yamacraw Design Center
#  Atlanta
#  GA
#  USA
# Yamacraw Design Center
#  Atlanta
#  GA
#  USA
# Yamacraw Design Center
#  Atlanta
#  GA
#  USA
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Lucent Technol. Bell Labs.
#  Murray Hill
#  NJ
#  USA
# Sch. of Electr. & Comput. Eng.
#  Atlanta
#  GA
#  USA
# Sch. of Electr. & Comput. Eng.
#  Atlanta
#  GA
#  USA
# Sch. of Electr. & Comput. Eng.
#  West Lafayette
#  IN
#  USA
# Sch. of Electr. & Comput. Eng.
#  West Lafayette
#  IN
#  USA
# 71/32 valid Affiliations, or the 221.88 precent.

# %%
df
# Out:
#                                              abstract  \
# 0   Self-heating effects and temperature rise in A...
# 1   AlGaN/GaN high electron mobility transistors (...
# 2   The characteristics of a novel nitride based f...
# 3   In this letter, we demonstrate that, for high ...
# 4   Silicon offers multiple advantages to power ci...
# 5   Metal-organic vapor phase epitaxy (MOVPE) and ...
# 6   Wide bandgap semiconductors are extremely attr...
# 7   The low temperature (100/spl deg/C) deposition...
# 8                                                 NaN
# 9   A novel p-capped GaN-AlGaN-GaN high-electron m...
# 10  Nonlinearities in GaN MESFETs are reported usi...
# 11  High-performance AlGaN/GaN high electron-mobil...
# 12  The authors experimentally investigate and dis...
# 13  We report low microwave noise performance of d...
# 14  A two-dimensional electron gas system (2DEG) i...
# 15  High electron mobility transistors (HEMTs) wer...
# 16                                                NaN
# 17  Proposes an accurate model to investigate the ...
# 18  Dynamic loadline analysis illustrating the mic...
# 19  DC current-switching and power-switching trans...
# 20  A 36-dBm high-linearity single-ended common-so...
# 21  A high-efficiency and compact AlGaN/GaN hetero...
# 22  The RF linearity of a 9-mm 10-W GaN high elect...
# 23  Reports on the power and microwave noise perfo...
# 24  A novel low-temperature nitride passivation te...
# 25  Reports on the CW power performance at 20 and ...
# 26  The high potential at microwave frequencies of...
# 27  Modeling procedures of an AlGaN/GaN HFET that ...
# 28  We present in this letter the benefits of GaN-...
# 29  High electron mobility transistors (HEMTs) are...
# 30  We present a theoretical model of an AlGaN-GaN...
# 31  Intrinsic noise sources and their correlation ...
#
#                                      abstract_url access_type  article_number  \
# 0   https://ieeexplore.ieee.org/document/1019941/      LOCKED         1019941
# 1   https://ieeexplore.ieee.org/document/1021091/      LOCKED         1021091
# 2   https://ieeexplore.ieee.org/document/1021092/      LOCKED         1021092
# 3   https://ieeexplore.ieee.org/document/1021093/      LOCKED         1021093
# 4   https://ieeexplore.ieee.org/document/1021562/      LOCKED         1021562
# 5   https://ieeexplore.ieee.org/document/1021564/      LOCKED         1021564
# 6   https://ieeexplore.ieee.org/document/1021567/      LOCKED         1021567
# 7   https://ieeexplore.ieee.org/document/1028981/      LOCKED         1028981
# 8   https://ieeexplore.ieee.org/document/1032885/    EPHEMERA         1032885
# 9   https://ieeexplore.ieee.org/document/1039176/      LOCKED         1039176
# 10  https://ieeexplore.ieee.org/document/1046018/      LOCKED         1046018
# 11  https://ieeexplore.ieee.org/document/1046021/      LOCKED         1046021
# 12  https://ieeexplore.ieee.org/document/1047035/      LOCKED         1047035
# 13  https://ieeexplore.ieee.org/document/1097937/      LOCKED         1097937
# 14  https://ieeexplore.ieee.org/document/1134207/      LOCKED         1134207
# 15  https://ieeexplore.ieee.org/document/1177950/      LOCKED         1177950
# 16  https://ieeexplore.ieee.org/document/1179386/    EPHEMERA         1179386
# 17  https://ieeexplore.ieee.org/document/1179387/      LOCKED         1179387
# 18  https://ieeexplore.ieee.org/document/1179388/      LOCKED         1179388
# 19  https://ieeexplore.ieee.org/document/1179390/      LOCKED         1179390
# 20  https://ieeexplore.ieee.org/document/1179391/      LOCKED         1179391
# 21  https://ieeexplore.ieee.org/document/1179392/      LOCKED         1179392
# 22  https://ieeexplore.ieee.org/document/1179393/      LOCKED         1179393
# 23  https://ieeexplore.ieee.org/document/1179394/      LOCKED         1179394
# 24  https://ieeexplore.ieee.org/document/1185193/      LOCKED         1185193
# 25  https://ieeexplore.ieee.org/document/1187392/      LOCKED         1187392
# 26  https://ieeexplore.ieee.org/document/1187394/      LOCKED         1187394
# 27  https://ieeexplore.ieee.org/document/1193046/      LOCKED         1193046
# 28  https://ieeexplore.ieee.org/document/1193049/      LOCKED         1193049
# 29  https://ieeexplore.ieee.org/document/1196015/      LOCKED         1196015
# 30  https://ieeexplore.ieee.org/document/1196072/      LOCKED         1196072
# 31  https://ieeexplore.ieee.org/document/1196189/      LOCKED         1196189
#
#     citing_paper_count  citing_patent_count content_type  \
# 0                  137                    3     Journals
# 1                  175                    9     Journals
# 2                   99                   13     Journals
# 3                   15                    2     Journals
# 4                  302                   18     Journals
# 5                   33                    4     Journals
# 6                 1307                  142     Journals
# 7                   41                    0     Journals
# 8                    0                    0     Journals
# 9                   43                    6     Journals
# 10                  10                    0     Journals
# 11                  31                    0     Journals
# 12                   8                    0     Journals
# 13                  52                    0     Journals
# 14                  38                    0     Journals
# 15                  11                    0     Journals
# 16                   0                    0     Journals
# 17                  23                    0     Journals
# 18                  33                    0     Journals
# 19                  54                    3     Journals
# 20                  47                    5     Journals
# 21                  38                    1     Journals
# 22                  36                   16     Journals
# 23                  27                    0     Journals
# 24                  11                    0     Journals
# 25                   6                    0     Journals
# 26                   4                    0     Journals
# 27                   9                    0     Journals
# 28                  18                    0     Journals
# 29                  30                    0     Journals
# 30                  36                    0     Journals
# 31                  40                    0     Journals
#
#                            doi end_page  \
# 0      10.1109/TED.2002.801430     1498
# 1      10.1109/LED.2002.801303      457
# 2      10.1109/LED.2002.801316      460
# 3      10.1109/LED.2002.801328      463
# 4   10.1109/JPROC.2002.1021562      986
# 5   10.1109/JPROC.2002.1021564     1005
# 6   10.1109/JPROC.2002.1021567     1031
# 7      10.1109/LED.2002.802592      507
# 8     10.1109/TIM.1990.1032885       69
# 9      10.1109/LED.2002.803764      590
# 10    10.1109/TMTT.2002.804518     2479
# 11    10.1109/TMTT.2002.804619     2504
# 12    10.1109/LMWC.2002.805532      423
# 13     10.1109/LED.2002.803766      639
# 14     10.1109/TNS.2002.805358     2707
# 15     10.1109/LED.2002.806298      693
# 16    10.1109/TMTT.2002.807679      606
# 17    10.1109/TMTT.2002.807678      617
# 18    10.1109/TMTT.2002.807680      623
# 19    10.1109/TMTT.2002.807687      642
# 20    10.1109/TMTT.2002.807682      652
# 21    10.1109/TMTT.2002.807685      659
# 22    10.1109/TMTT.2002.807684      664
# 23    10.1109/TMTT.2002.807683      668
# 24     10.1109/LED.2002.807313        9
# 25    10.1109/LMWC.2003.810115       95
# 26    10.1109/LMWC.2003.810117      101
# 27    10.1109/LMWC.2003.811062      142
# 28    10.1109/LMWC.2003.811057      151
# 29     10.1109/LED.2002.807693       59
# 30     10.1109/TED.2002.808519      323
# 31    10.1109/TMTT.2003.810140     1577
#
#                                          html_url  ...  \
# 0   https://ieeexplore.ieee.org/document/1019941/  ...
# 1   https://ieeexplore.ieee.org/document/1021091/  ...
# 2   https://ieeexplore.ieee.org/document/1021092/  ...
# 3   https://ieeexplore.ieee.org/document/1021093/  ...
# 4   https://ieeexplore.ieee.org/document/1021562/  ...
# 5   https://ieeexplore.ieee.org/document/1021564/  ...
# 6   https://ieeexplore.ieee.org/document/1021567/  ...
# 7   https://ieeexplore.ieee.org/document/1028981/  ...
# 8   https://ieeexplore.ieee.org/document/1032885/  ...
# 9   https://ieeexplore.ieee.org/document/1039176/  ...
# 10  https://ieeexplore.ieee.org/document/1046018/  ...
# 11  https://ieeexplore.ieee.org/document/1046021/  ...
# 12  https://ieeexplore.ieee.org/document/1047035/  ...
# 13  https://ieeexplore.ieee.org/document/1097937/  ...
# 14  https://ieeexplore.ieee.org/document/1134207/  ...
# 15  https://ieeexplore.ieee.org/document/1177950/  ...
# 16  https://ieeexplore.ieee.org/document/1179386/  ...
# 17  https://ieeexplore.ieee.org/document/1179387/  ...
# 18  https://ieeexplore.ieee.org/document/1179388/  ...
# 19  https://ieeexplore.ieee.org/document/1179390/  ...
# 20  https://ieeexplore.ieee.org/document/1179391/  ...
# 21  https://ieeexplore.ieee.org/document/1179392/  ...
# 22  https://ieeexplore.ieee.org/document/1179393/  ...
# 23  https://ieeexplore.ieee.org/document/1179394/  ...
# 24  https://ieeexplore.ieee.org/document/1185193/  ...
# 25  https://ieeexplore.ieee.org/document/1187392/  ...
# 26  https://ieeexplore.ieee.org/document/1187394/  ...
# 27  https://ieeexplore.ieee.org/document/1193046/  ...
# 28  https://ieeexplore.ieee.org/document/1193049/  ...
# 29  https://ieeexplore.ieee.org/document/1196015/  ...
# 30  https://ieeexplore.ieee.org/document/1196072/  ...
# 31  https://ieeexplore.ieee.org/document/1196189/  ...
#
#     index_terms.author_terms.terms        Country      Continent CategoryOBC  \
# 0                                        Slovakia         Europe         NaN
# 1                                             USA  North America         NaN
# 2                                             USA  North America         NaN
# 3                                          France         Europe         NaN
# 4                                             USA  North America         NaN
# 5                                             USA  North America         NaN
# 6                                             USA  North America         NaN
# 7                                             USA  North America         NaN
# 8                                   Uncategorized  Uncategorized         NaN
# 9                                             USA  North America         NaN
# 10                                            USA  North America         NaN
# 11                                            USA  North America         NaN
# 12                                            USA  North America         NaN
# 13                                            USA  North America         NaN
# 14                                         Canada  North America         NaN
# 15                                            USA  North America         NaN
# 16                                  Uncategorized  Uncategorized         NaN
# 17                                          India           Asia         NaN
# 18                                            USA  North America         NaN
# 19                                        Germany         Europe         NaN
# 20                                            USA  North America         NaN
# 21                                            USA  North America         NaN
# 22                                            USA  North America         NaN
# 23                                            USA  North America         NaN
# 24                                            USA  North America         NaN
# 25                                            USA  North America         NaN
# 26                                         France         Europe         NaN
# 27                                            USA  North America         NaN
# 28                                            USA  North America         NaN
# 29                                            USA  North America         NaN
# 30                                            USA  North America         NaN
# 31                                            USA  North America         NaN
#
#    CategoryGaN  CategorySiC CategoryInverter  CategoryDCDC Categorization  \
# 0          GaN          NaN              NaN           NaN            GaN
# 1          GaN          SiC              NaN           NaN        GaN;SiC
# 2          GaN          NaN              NaN           NaN            GaN
# 3          GaN          NaN              NaN           NaN            GaN
# 4          NaN          SiC              NaN           NaN            SiC
# 5          GaN          NaN              NaN           NaN            GaN
# 6          GaN          NaN              NaN           NaN            GaN
# 7          GaN          NaN              NaN           NaN            GaN
# 8          GaN          NaN              NaN           NaN            GaN
# 9          GaN          NaN              NaN           NaN            GaN
# 10         GaN          NaN              NaN           NaN            GaN
# 11         GaN          NaN              NaN           NaN            GaN
# 12         GaN          NaN              NaN           NaN            GaN
# 13         GaN          NaN              NaN           NaN            GaN
# 14         GaN          NaN              NaN           NaN            GaN
# 15         GaN          NaN              NaN           NaN            GaN
# 16         GaN          SiC              NaN           NaN        GaN;SiC
# 17         GaN          NaN              NaN           NaN            GaN
# 18         GaN          NaN              NaN           NaN            GaN
# 19         GaN          NaN              NaN           NaN            GaN
# 20         GaN          NaN              NaN           NaN            GaN
# 21         GaN          NaN              NaN           NaN            GaN
# 22         GaN          NaN              NaN           NaN            GaN
# 23         GaN          NaN              NaN           NaN            GaN
# 24         GaN          NaN              NaN           NaN            GaN
# 25         GaN          SiC              NaN           NaN        GaN;SiC
# 26         GaN          NaN              NaN           NaN            GaN
# 27         GaN          NaN              NaN           NaN            GaN
# 28         GaN          NaN              NaN           NaN            GaN
# 29         GaN          NaN              NaN           NaN            GaN
# 30         GaN          NaN              NaN           NaN            GaN
# 31         GaN          NaN              NaN           NaN            GaN
#
#                                           Affiliation
# 0                               Inst. of Electr. Eng.
# 1                                      Illinois Univ.
# 2                                South Carolina Univ.
# 3   Inst. dElectronique et de Microelectronique du...
# 4                                       Uncategorized
# 5                          North Carolina State Univ.
# 6                                    California Univ.
# 7                                       Uncategorized
# 8                                 Clarkson University
# 9                                    California Univ.
# 10                        Rochester Inst. of Technol.
# 11                                     Illinois Univ.
# 12                                   California Univ.
# 13                                      Uncategorized
# 14                                   Sherbrooke Univ.
# 15                                      Uncategorized
# 16                                      Uncategorized
# 17                                     Univ. of Delhi
# 18                                      Cornell Univ.
# 19                                       Univ. of Ulm
# 20                                Univ. of California
# 21                                Univ. of California
# 22                                      Uncategorized
# 23                                      Uncategorized
# 24                                      Uncategorized
# 25                                  Univ. of Illinois
# 26  Inst. dElectronique et de Microelectronique du...
# 27                          Georgia Inst. of Technol.
# 28                          Georgia Inst. of Technol.
# 29                                      Uncategorized
# 30                          Georgia Inst. of Technol.
# 31                                       Purdue Univ.
#
# [32 rows x 35 columns]
