# %%
import sys

sys.path.append("/home/alex-anast/workspace/ieee-papers-mapper/")

# %%
from src.ieee_papers_mapper.config import config as cfg
from src.ieee_papers_mapper.data.get_papers import get_papers
import pandas as pd

# %%
df_raw = get_papers(
    query="machine learning",
    api_key=cfg.IEEE_API_KEY,
    start_year=2024,
    start_record=-11,
    max_records=10,
)

# %%
df_raw
# Out:
#                           doi  \
# 0   10.1109/TCYB.2022.3228303
# 1   10.1109/TCSS.2022.3230823
# 2   10.1109/TASE.2022.3231386
# 3  10.1109/TNNLS.2022.3224577
# 4  10.1109/TNNLS.2022.3230426
# 5  10.1109/TNNLS.2022.3232394
# 6   10.1109/TCSS.2022.3230974
# 7  10.1109/TNNLS.2022.3232106
# 8   10.1109/TCSS.2022.3232117
# 9  10.1109/TNNLS.2022.3232532
#
#                                                title publisher issue  \
# 0  Incremental Fuzzy Clustering-Based Neural Netw...      IEEE     5
# 1  Tweet Spam Detection Using Machine Learning an...      IEEE     4
# 2  How Useful is Learning in Mitigating Mismatch ...      IEEE     1
# 3                           Positive-Incentive Noise      IEEE     6
# 4  An Adaptive Image Segmentation Network for Sur...      IEEE     6
# 5  Reweighted Regularized Prototypical Network fo...      IEEE     5
# 6  MTBullyGNN: A Graph Neural Network-Based Multi...      IEEE     1
# 7  Hierarchical Spiking-Based Model for Efficient...      IEEE     7
# ...
